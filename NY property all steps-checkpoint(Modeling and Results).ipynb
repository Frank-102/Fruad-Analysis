# %%
from datetime import datetime
start_time = datetime.now()

# Load libraries
# %pip install keras
# %pip install tensorflow

import pandas as pd
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
# %matplotlib inline

print('LOAD DURATION:',datetime.now() - start_time) # about 3 minutes
# Out:
# LOAD DURATION: 0:00:01.813122

# %%
# %%time
property_data = pd.read_csv('NY property data.csv')
NY_data_orig = property_data.copy()
# Out:
# Wall time: 2.39 s

# %%
property_data.shape
# Out:
# (1070994, 32)

# %%
property_data.head().transpose()
# Out:
#                               0                      1                      2  \
# RECORD                        1                      2                      3
# BBLE                 1000010101             1000010201             1000020001
# B                             1                      1                      1
# BLOCK                         1                      1                      2
# LOT                         101                    201                      1
# EASEMENT                    NaN                    NaN                    NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS  DEPT OF GENERAL SERVI
# BLDGCL                       P7                     Z9                     Y7
# TAXCLASS                      4                      4                      4
# LTFRONT                     500                     27                    709
# LTDEPTH                    1046                      0                    564
# EXT                         NaN                    NaN                      E
# STORIES                     NaN                    NaN                      3
# FULLVAL                2.14e+07              1.938e+08            1.04686e+08
# AVLAND               4.2255e+06              1.431e+07            3.90087e+07
# AVTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXLAND               4.2255e+06              1.431e+07            3.90087e+07
# EXTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXCD1                      4600                   4600                   2191
# STADDR         1 LIBERTY ISLAND         1 ELLIS ISLAND        MARGINAL STREET
# ZIP                       10004                  10004                  10004
# EXMPTCL                      X3                     X3                     X1
# BLDFRONT                      0                      0                    709
# BLDDEPTH                      0                      0                    564
# AVLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# AVTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# EXTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXCD2                       NaN                    NaN                    NaN
# PERIOD                    FINAL                  FINAL                  FINAL
# YEAR                    2010/11                2010/11                2010/11
# VALTYPE                   AC-TR                  AC-TR                  AC-TR
#
#                               3                     4
# RECORD                        4                     5
# BBLE                 1000020023            1000030001
# B                             1                     1
# BLOCK                         2                     3
# LOT                          23                     1
# EASEMENT                    NaN                   NaN
# OWNER     DEPARTMENT OF BUSINES  PARKS AND RECREATION
# BLDGCL                       T2                    Q1
# TAXCLASS                      4                     4
# LTFRONT                     793                   323
# LTDEPTH                     551                  1260
# EXT                         NaN                   NaN
# STORIES                       2                     1
# FULLVAL                3.92e+07             2.723e+08
# AVLAND               1.5255e+07            1.2105e+08
# AVTOT                 1.764e+07           1.22535e+08
# EXLAND               1.5255e+07            1.2105e+08
# EXTOT                 1.764e+07           1.22535e+08
# EXCD1                      2191                  2231
# STADDR                   PIER 6          BATTERY PARK
# ZIP                       10004                 10004
# EXMPTCL                      X1                    X1
# BLDFRONT                     85                    89
# BLDDEPTH                    551                    57
# AVLAND2              1.3644e+07           1.06349e+08
# AVTOT2                1.575e+07           1.07758e+08
# EXLAND2              1.3644e+07           1.06349e+08
# EXTOT2                1.575e+07           1.07758e+08
# EXCD2                       NaN                   NaN
# PERIOD                    FINAL                 FINAL
# YEAR                    2010/11               2010/11
# VALTYPE                   AC-TR                 AC-TR

# %%
numrecs = len(property_data)
numrecs
# Out:
# 1070994

# %% [markdown]
# ## Fill in missing ZIP

# %%
missing_zips = np.where(pd.isnull(property_data['ZIP']))[0]
len(missing_zips)
# Out:
# 29890

# %%
for i in range(len(missing_zips)):
    if(property_data.loc[missing_zips[i]+1,'ZIP'] == property_data.loc[missing_zips[i]-1,'ZIP']):
        property_data.loc[missing_zips[i],'ZIP'] = property_data.loc[missing_zips[i]-1,'ZIP']

# %%
missing_zips = np.where(pd.isnull(property_data['ZIP']))[0]
len(missing_zips)
# Out:
# 16437

# %%
for i in range(len(missing_zips)):
    property_data.loc[missing_zips[i],'ZIP'] = property_data.loc[missing_zips[i]-1,'ZIP']  # use the nearest zipcode to replace these missing values

# %%
missing_zips = np.where(pd.isnull(property_data['ZIP']))[0]
len(missing_zips)
# Out:
# 0

# %% [markdown]
# ## Calculate means for AVTOT, AVLAND, FULLVAL by taxclass, avoiding the records with zeros

# %%
property_data['FULLVAL'].replace('NaN',0)
temp =property_data[property_data['FULLVAL']!=0]
mean_fullval = temp.groupby('TAXCLASS')['FULLVAL'].mean()
print(mean_fullval)
# Out:
# TAXCLASS
# 1     5.698435e+05
# 1A    3.352842e+05
# 1B    5.613639e+05
# 1C    7.615359e+05
# 1D    2.233614e+07
# 2     7.998018e+05
# 2A    8.640037e+05
# 2B    1.252989e+06
# 2C    7.728799e+05
# 3     1.112765e+05
# 4     3.211928e+06
# Name: FULLVAL, dtype: float64

# %%
property_data['AVLAND'].replace('NaN',0)
temp_avland = property_data[property_data['AVLAND']!=0]
mean_avland = temp_avland.groupby('TAXCLASS')['AVLAND'].mean()

# %%
property_data['AVTOT'].replace('NaN',0)
temp_avtot = property_data[property_data['AVTOT']!=0]
mean_avtot = temp_avtot.groupby('TAXCLASS')['AVTOT'].mean()

# %% [markdown]
# ## Substituting decent values for AVTOT, AVLAND, FULLVAL from averages by taxclass

# %%
# %%time
for index in mean_fullval.index:
    property_data.loc[(property_data['FULLVAL']==0)&(property_data['TAXCLASS']==index),'FULLVAL']=mean_fullval[index]
    property_data.loc[(property_data['AVLAND']==0)&(property_data['TAXCLASS']==index),'AVLAND']=mean_avland[index]
    property_data.loc[(property_data['AVTOT']==0)&(property_data['TAXCLASS']==index),'AVTOT']=mean_avtot[index]
# Out:
# Wall time: 1.59 s

# %%
property_data.head().transpose()
# Out:
#                               0                      1                      2  \
# RECORD                        1                      2                      3
# BBLE                 1000010101             1000010201             1000020001
# B                             1                      1                      1
# BLOCK                         1                      1                      2
# LOT                         101                    201                      1
# EASEMENT                    NaN                    NaN                    NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS  DEPT OF GENERAL SERVI
# BLDGCL                       P7                     Z9                     Y7
# TAXCLASS                      4                      4                      4
# LTFRONT                     500                     27                    709
# LTDEPTH                    1046                      0                    564
# EXT                         NaN                    NaN                      E
# STORIES                     NaN                    NaN                      3
# FULLVAL                2.14e+07              1.938e+08            1.04686e+08
# AVLAND               4.2255e+06              1.431e+07            3.90087e+07
# AVTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXLAND               4.2255e+06              1.431e+07            3.90087e+07
# EXTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXCD1                      4600                   4600                   2191
# STADDR         1 LIBERTY ISLAND         1 ELLIS ISLAND        MARGINAL STREET
# ZIP                       10004                  10004                  10004
# EXMPTCL                      X3                     X3                     X1
# BLDFRONT                      0                      0                    709
# BLDDEPTH                      0                      0                    564
# AVLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# AVTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# EXTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXCD2                       NaN                    NaN                    NaN
# PERIOD                    FINAL                  FINAL                  FINAL
# YEAR                    2010/11                2010/11                2010/11
# VALTYPE                   AC-TR                  AC-TR                  AC-TR
#
#                               3                     4
# RECORD                        4                     5
# BBLE                 1000020023            1000030001
# B                             1                     1
# BLOCK                         2                     3
# LOT                          23                     1
# EASEMENT                    NaN                   NaN
# OWNER     DEPARTMENT OF BUSINES  PARKS AND RECREATION
# BLDGCL                       T2                    Q1
# TAXCLASS                      4                     4
# LTFRONT                     793                   323
# LTDEPTH                     551                  1260
# EXT                         NaN                   NaN
# STORIES                       2                     1
# FULLVAL                3.92e+07             2.723e+08
# AVLAND               1.5255e+07            1.2105e+08
# AVTOT                 1.764e+07           1.22535e+08
# EXLAND               1.5255e+07            1.2105e+08
# EXTOT                 1.764e+07           1.22535e+08
# EXCD1                      2191                  2231
# STADDR                   PIER 6          BATTERY PARK
# ZIP                       10004                 10004
# EXMPTCL                      X1                    X1
# BLDFRONT                     85                    89
# BLDDEPTH                    551                    57
# AVLAND2              1.3644e+07           1.06349e+08
# AVTOT2                1.575e+07           1.07758e+08
# EXLAND2              1.3644e+07           1.06349e+08
# EXTOT2                1.575e+07           1.07758e+08
# EXCD2                       NaN                   NaN
# PERIOD                    FINAL                 FINAL
# YEAR                    2010/11               2010/11
# VALTYPE                   AC-TR                 AC-TR

# %% [markdown]
# ## STORIES

# %%
temp = property_data[property_data['STORIES'].isnull()]
len(temp)
# Out:
# 56264

# %%
temp['TAXCLASS'].value_counts()
# Out:
# 1B    24736
# 4     22354
# 3      4635
# 2      3435
# 1       897
# 2C      138
# 2B       34
# 2A       30
# 1A        5
# Name: TAXCLASS, dtype: int64

# %%
mean_stories = property_data.groupby('TAXCLASS')['STORIES'].mean()
print(mean_stories)
# Out:
# TAXCLASS
# 1      2.111641
# 1A     1.656837
# 1B     4.000000
# 1C     3.052748
# 1D     1.068966
# 2     16.095110
# 2A     2.844574
# 2B     4.004494
# 2C     4.745097
# 3      1.333333
# 4      5.446968
# Name: STORIES, dtype: float64

# %%
temp.head().transpose()
# Out:
#                              0                      1                     5   \
# RECORD                        1                      2                     6
# BBLE                 1000010101             1000010201            1000030002
# B                             1                      1                     1
# BLOCK                         1                      1                     3
# LOT                         101                    201                     2
# EASEMENT                    NaN                    NaN                   NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS  PARKS AND RECREATION
# BLDGCL                       P7                     Z9                    Q1
# TAXCLASS                      4                      4                     4
# LTFRONT                     500                     27                   496
# LTDEPTH                    1046                      0                    76
# EXT                         NaN                    NaN                   NaN
# STORIES                     NaN                    NaN                   NaN
# FULLVAL                2.14e+07              1.938e+08              1.06e+07
# AVLAND               4.2255e+06              1.431e+07              4.77e+06
# AVTOT                  9.63e+06              8.721e+07              4.77e+06
# EXLAND               4.2255e+06              1.431e+07              4.77e+06
# EXTOT                  9.63e+06              8.721e+07              4.77e+06
# EXCD1                      4600                   4600                  2231
# STADDR         1 LIBERTY ISLAND         1 ELLIS ISLAND    PETER MINUIT PLAZA
# ZIP                       10004                  10004                 10004
# EXMPTCL                      X3                     X3                    X1
# BLDFRONT                      0                      0                     0
# BLDDEPTH                      0                      0                     0
# AVLAND2              3.7755e+06            1.11114e+07            4.2687e+06
# AVTOT2                8.613e+06            8.06904e+07            4.2687e+06
# EXLAND2              3.7755e+06            1.11114e+07            4.2687e+06
# EXTOT2                8.613e+06            8.06904e+07            4.2687e+06
# EXCD2                       NaN                    NaN                   NaN
# PERIOD                    FINAL                  FINAL                 FINAL
# YEAR                    2010/11                2010/11               2010/11
# VALTYPE                   AC-TR                  AC-TR                 AC-TR
#
#                               65                      66
# RECORD                        66                      67
# BBLE                  1000051004              1000051005
# B                              1                       1
# BLOCK                          5                       5
# LOT                         1004                    1005
# EASEMENT                     NaN                     NaN
# OWNER       SLG BROAD STREET 125   AMERICAN CIVIL LIBERT
# BLDGCL                        R5                      R5
# TAXCLASS                       4                       4
# LTFRONT                        0                       0
# LTDEPTH                        0                       0
# EXT                          NaN                     NaN
# STORIES                      NaN                     NaN
# FULLVAL               5.2668e+06              5.2668e+06
# AVLAND                    858211                  858211
# AVTOT                2.37006e+06             2.37006e+06
# EXLAND                    858211                  858211
# EXTOT                2.37006e+06             2.37006e+06
# EXCD1                       1501                    1501
# STADDR    2 AMERICAN EXPRESS PLZ  2 AMERICAN EXPRESS PLZ
# ZIP                        10004                   10004
# EXMPTCL                      NaN                     NaN
# BLDFRONT                       0                       0
# BLDDEPTH                       0                       0
# AVLAND2                   856725                  856725
# AVTOT2               2.02527e+06             2.02527e+06
# EXLAND2                   856725                  856725
# EXTOT2               2.02527e+06             2.02527e+06
# EXCD2                        NaN                     NaN
# PERIOD                     FINAL                   FINAL
# YEAR                     2010/11                 2010/11
# VALTYPE                    AC-TR                   AC-TR

# %%
len(property_data[property_data["STORIES"]==0]) # check the missing values
# Out:
# 0

# %%
property_data['STORIES']=property_data['STORIES'].fillna(value =0)
for index in mean_stories.index:
    property_data.loc[(property_data['STORIES']==0)&(property_data['TAXCLASS']==index),'STORIES']=mean_stories[index]

# %%
property_data.head().transpose()
# Out:
#                               0                      1                      2  \
# RECORD                        1                      2                      3
# BBLE                 1000010101             1000010201             1000020001
# B                             1                      1                      1
# BLOCK                         1                      1                      2
# LOT                         101                    201                      1
# EASEMENT                    NaN                    NaN                    NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS  DEPT OF GENERAL SERVI
# BLDGCL                       P7                     Z9                     Y7
# TAXCLASS                      4                      4                      4
# LTFRONT                     500                     27                    709
# LTDEPTH                    1046                      0                    564
# EXT                         NaN                    NaN                      E
# STORIES                 5.44697                5.44697                      3
# FULLVAL                2.14e+07              1.938e+08            1.04686e+08
# AVLAND               4.2255e+06              1.431e+07            3.90087e+07
# AVTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXLAND               4.2255e+06              1.431e+07            3.90087e+07
# EXTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXCD1                      4600                   4600                   2191
# STADDR         1 LIBERTY ISLAND         1 ELLIS ISLAND        MARGINAL STREET
# ZIP                       10004                  10004                  10004
# EXMPTCL                      X3                     X3                     X1
# BLDFRONT                      0                      0                    709
# BLDDEPTH                      0                      0                    564
# AVLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# AVTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# EXTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXCD2                       NaN                    NaN                    NaN
# PERIOD                    FINAL                  FINAL                  FINAL
# YEAR                    2010/11                2010/11                2010/11
# VALTYPE                   AC-TR                  AC-TR                  AC-TR
#
#                               3                     4
# RECORD                        4                     5
# BBLE                 1000020023            1000030001
# B                             1                     1
# BLOCK                         2                     3
# LOT                          23                     1
# EASEMENT                    NaN                   NaN
# OWNER     DEPARTMENT OF BUSINES  PARKS AND RECREATION
# BLDGCL                       T2                    Q1
# TAXCLASS                      4                     4
# LTFRONT                     793                   323
# LTDEPTH                     551                  1260
# EXT                         NaN                   NaN
# STORIES                       2                     1
# FULLVAL                3.92e+07             2.723e+08
# AVLAND               1.5255e+07            1.2105e+08
# AVTOT                 1.764e+07           1.22535e+08
# EXLAND               1.5255e+07            1.2105e+08
# EXTOT                 1.764e+07           1.22535e+08
# EXCD1                      2191                  2231
# STADDR                   PIER 6          BATTERY PARK
# ZIP                       10004                 10004
# EXMPTCL                      X1                    X1
# BLDFRONT                     85                    89
# BLDDEPTH                    551                    57
# AVLAND2              1.3644e+07           1.06349e+08
# AVTOT2                1.575e+07           1.07758e+08
# EXLAND2              1.3644e+07           1.06349e+08
# EXTOT2                1.575e+07           1.07758e+08
# EXCD2                       NaN                   NaN
# PERIOD                    FINAL                 FINAL
# YEAR                    2010/11               2010/11
# VALTYPE                   AC-TR                 AC-TR

# %% [markdown]
# ## Fill in LTFRONT, LTDEPTH, BLDDEPTH, BLDFRONT with averages by TAXCLASS

# %%
# %%time
# as these 4 values do not have NAs, we just need to replace 0s. 
# calculate groupwise average. 1st replace 0 by NAs so they are not counted in calculating mean.
property_data.loc[property_data['LTFRONT']==0,'LTFRONT']=np.nan
property_data.loc[property_data['LTDEPTH']==0,'LTDEPTH']=np.nan
property_data.loc[property_data['BLDFRONT']==0,'BLDFRONT']=np.nan
property_data.loc[property_data['BLDDEPTH']==0,'BLDDEPTH']=np.nan

property_data.loc[property_data['LTFRONT']==1,'LTFRONT']=np.nan
property_data.loc[property_data['LTDEPTH']==1,'LTDEPTH']=np.nan
property_data.loc[property_data['BLDFRONT']==1,'BLDFRONT']=np.nan
property_data.loc[property_data['BLDDEPTH']==1,'BLDDEPTH']=np.nan

#calculate mean now (mean function ignores NAs but not 0s hence we converted 0 to NA)
mean_LTFRONT=property_data.groupby(property_data['TAXCLASS'])['LTFRONT'].mean()
mean_LTDEPTH=property_data.groupby(property_data['TAXCLASS'])['LTDEPTH'].mean()
mean_BLDFRONT=property_data.groupby(property_data['TAXCLASS'])['BLDFRONT'].mean()
mean_BLDDEPTH=property_data.groupby(property_data['TAXCLASS'])['BLDDEPTH'].mean()

#impute values
for index in mean_LTFRONT.index:
    property_data.loc[(property_data['LTFRONT'].isnull())&(property_data['TAXCLASS']==index),'LTFRONT']=mean_LTFRONT[index]    
    property_data.loc[(property_data['LTDEPTH'].isnull())&(property_data['TAXCLASS']==index),'LTDEPTH']=mean_LTDEPTH[index]
    property_data.loc[(property_data['BLDFRONT'].isnull())&(property_data['TAXCLASS']==index),'BLDFRONT']=mean_BLDFRONT[index]
    property_data.loc[(property_data['BLDDEPTH'].isnull())&(property_data['TAXCLASS']==index),'BLDDEPTH']=mean_BLDDEPTH[index]
# Out:
# Wall time: 2.39 s

# %%
mean_LTFRONT
# Out:
# TAXCLASS
# 1      30.939072
# 1A     51.124586
# 1B     54.610260
# 1C     27.250825
# 1D    338.275862
# 2     113.541391
# 2A     25.917860
# 2B     27.254835
# 2C     29.987290
# 3     136.107963
# 4      93.937119
# Name: LTFRONT, dtype: float64

# %%
mean_LTDEPTH
# Out:
# TAXCLASS
# 1      99.282535
# 1A     90.083551
# 1B    111.856649
# 1C     96.778878
# 1D    497.827586
# 2     132.606230
# 2A     97.282675
# 2B     95.751182
# 2C     95.737463
# 3     280.837313
# 4     133.871567
# Name: LTDEPTH, dtype: float64

# %%
mean_BLDFRONT
# Out:
# TAXCLASS
# 1     21.401447
# 1A    25.024532
# 1B    39.500000
# 1C    23.367589
# 1D    19.586207
# 2     92.203204
# 2A    22.983862
# 2B    26.042747
# 2C    27.888318
# 3     19.333333
# 4     64.439787
# Name: BLDFRONT, dtype: float64

# %%
mean_BLDDEPTH
# Out:
# TAXCLASS
# 1      41.556940
# 1A     44.949251
# 1B     82.666667
# 1C     60.094862
# 1D     36.862069
# 2     108.005699
# 2A     62.430662
# 2B     66.587020
# 2C     68.660429
# 3      33.750000
# 4      87.820730
# Name: BLDDEPTH, dtype: float64

# %%
data = property_data.copy()
data.shape
# Out:
# (1070994, 32)

# %%
data.dtypes
# Out:
# RECORD        int64
# BBLE         object
# B             int64
# BLOCK         int64
# LOT           int64
# EASEMENT     object
# OWNER        object
# BLDGCL       object
# TAXCLASS     object
# LTFRONT     float64
# LTDEPTH     float64
# EXT          object
# STORIES     float64
# FULLVAL     float64
# AVLAND      float64
# AVTOT       float64
# EXLAND      float64
# EXTOT       float64
# EXCD1       float64
# STADDR       object
# ZIP         float64
# EXMPTCL      object
# BLDFRONT    float64
# BLDDEPTH    float64
# AVLAND2     float64
# AVTOT2      float64
# EXLAND2     float64
# EXTOT2      float64
# EXCD2       float64
# PERIOD       object
# YEAR         object
# VALTYPE      object
# dtype: object

# %%
# convert ZIP to an integer rather than a float
data['ZIP'] = data['ZIP'].astype(str)
data['zip3'] = data['ZIP'].str[:3]

# %%
data.count()
# Out:
# RECORD      1070994
# BBLE        1070994
# B           1070994
# BLOCK       1070994
# LOT         1070994
# EASEMENT       4636
# OWNER       1039249
# BLDGCL      1070994
# TAXCLASS    1070994
# LTFRONT     1070994
# LTDEPTH     1070994
# EXT          354305
# STORIES     1014730
# FULLVAL     1070994
# AVLAND      1070994
# AVTOT       1070994
# EXLAND      1070994
# EXTOT       1070994
# EXCD1        638488
# STADDR      1070318
# ZIP         1070994
# EXMPTCL       15579
# BLDFRONT    1070994
# BLDDEPTH    1070994
# AVLAND2      282726
# AVTOT2       282732
# EXLAND2       87449
# EXTOT2       130828
# EXCD2         92948
# PERIOD      1070994
# YEAR        1070994
# VALTYPE     1070994
# zip3        1070994
# dtype: int64

# %%
cols = data.columns
print(cols)
# Out:
# Index(['RECORD', 'BBLE', 'B', 'BLOCK', 'LOT', 'EASEMENT', 'OWNER', 'BLDGCL',
#        'TAXCLASS', 'LTFRONT', 'LTDEPTH', 'EXT', 'STORIES', 'FULLVAL', 'AVLAND',
#        'AVTOT', 'EXLAND', 'EXTOT', 'EXCD1', 'STADDR', 'ZIP', 'EXMPTCL',
#        'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2', 'EXLAND2', 'EXTOT2',
#        'EXCD2', 'PERIOD', 'YEAR', 'VALTYPE', 'zip3'],
#       dtype='object')

# %%
data['ltsize'] = data['LTFRONT'] * data['LTDEPTH']
data['bldsize'] = data['BLDFRONT'] * data['BLDDEPTH']
data['bldvol'] = data['bldsize'] * data['STORIES']

# %%
data.head().transpose()
# Out:
#                               0                      1                      2  \
# RECORD                        1                      2                      3
# BBLE                 1000010101             1000010201             1000020001
# B                             1                      1                      1
# BLOCK                         1                      1                      2
# LOT                         101                    201                      1
# EASEMENT                    NaN                    NaN                    NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS  DEPT OF GENERAL SERVI
# BLDGCL                       P7                     Z9                     Y7
# TAXCLASS                      4                      4                      4
# LTFRONT                     500                     27                    709
# LTDEPTH                    1046                133.872                    564
# EXT                         NaN                    NaN                      E
# STORIES                     NaN                    NaN                      3
# FULLVAL                2.14e+07              1.938e+08            1.04686e+08
# AVLAND               4.2255e+06              1.431e+07            3.90087e+07
# AVTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXLAND               4.2255e+06              1.431e+07            3.90087e+07
# EXTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXCD1                      4600                   4600                   2191
# STADDR         1 LIBERTY ISLAND         1 ELLIS ISLAND        MARGINAL STREET
# ZIP                     10004.0                10004.0                10004.0
# EXMPTCL                      X3                     X3                     X1
# BLDFRONT                64.4398                64.4398                    709
# BLDDEPTH                87.8207                87.8207                    564
# AVLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# AVTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# EXTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXCD2                       NaN                    NaN                    NaN
# PERIOD                    FINAL                  FINAL                  FINAL
# YEAR                    2010/11                2010/11                2010/11
# VALTYPE                   AC-TR                  AC-TR                  AC-TR
# zip3                        100                    100                    100
# ltsize                   523000                3614.53                 399876
# bldsize                 5659.15                5659.15                 399876
# bldvol                      NaN                    NaN            1.19963e+06
#
#                               3                     4
# RECORD                        4                     5
# BBLE                 1000020023            1000030001
# B                             1                     1
# BLOCK                         2                     3
# LOT                          23                     1
# EASEMENT                    NaN                   NaN
# OWNER     DEPARTMENT OF BUSINES  PARKS AND RECREATION
# BLDGCL                       T2                    Q1
# TAXCLASS                      4                     4
# LTFRONT                     793                   323
# LTDEPTH                     551                  1260
# EXT                         NaN                   NaN
# STORIES                       2                     1
# FULLVAL                3.92e+07             2.723e+08
# AVLAND               1.5255e+07            1.2105e+08
# AVTOT                 1.764e+07           1.22535e+08
# EXLAND               1.5255e+07            1.2105e+08
# EXTOT                 1.764e+07           1.22535e+08
# EXCD1                      2191                  2231
# STADDR                   PIER 6          BATTERY PARK
# ZIP                     10004.0               10004.0
# EXMPTCL                      X1                    X1
# BLDFRONT                     85                    89
# BLDDEPTH                    551                    57
# AVLAND2              1.3644e+07           1.06349e+08
# AVTOT2                1.575e+07           1.07758e+08
# EXLAND2              1.3644e+07           1.06349e+08
# EXTOT2                1.575e+07           1.07758e+08
# EXCD2                       NaN                   NaN
# PERIOD                    FINAL                 FINAL
# YEAR                    2010/11               2010/11
# VALTYPE                   AC-TR                 AC-TR
# zip3                        100                   100
# ltsize                   436943                406980
# bldsize                   46835                  5073
# bldvol                    93670                  5073

# %%
data['r1'] = data['FULLVAL'] / data['ltsize']
data['r2'] = data['FULLVAL'] / data['bldsize']
data['r3'] = data['FULLVAL'] / data['bldvol']
data['r4'] = data['AVLAND'] / data['ltsize']
data['r5'] = data['AVLAND'] / data['bldsize']
data['r6'] = data['AVLAND'] / data['bldvol']
data['r7'] = data['AVTOT'] / data['ltsize']
data['r8'] = data['AVTOT'] / data['bldsize']
data['r9'] = data['AVTOT'] / data['bldvol']  # building the new variables

# %%
# %%time
ninevars = ['r1','r2','r3','r4','r5','r6','r7','r8','r9']
zip5_mean = data.groupby('ZIP')[ninevars].mean()
zip3_mean = data.groupby('zip3')[ninevars].mean()   #groupby ? 

taxclass_mean = data.groupby('TAXCLASS')[ninevars].mean()
borough_mean = data.groupby('B')[ninevars].mean()
data = data.join(zip5_mean, on='ZIP', rsuffix='_zip5')  # data.join? 

data = data.join(zip3_mean, on='zip3', rsuffix='_zip3')
data = data.join(taxclass_mean, on='TAXCLASS', rsuffix='_taxclass')
data = data.join(borough_mean, on='B', rsuffix='_boro')
rsuffix = ['_zip5', '_zip3', '_taxclass', '_boro']
for var in ninevars:
    for r in rsuffix:
        data[str(var)+r] = data[var] / data[str(var)+r]
# Out:
# Wall time: 2.16 s

# %%
data.head().transpose()
# Out:
#                   0           1           2           3           4
# RECORD            1           2           3           4           5
# BBLE     1000010101  1000010201  1000020001  1000020023  1000030001
# B                 1           1           1           1           1
# BLOCK             1           1           2           2           3
# LOT             101         201           1          23           1
# ...             ...         ...         ...         ...         ...
# r5_boro     12.0252     40.7243     1.57109     5.24575     384.296
# r6_boro         NaN         NaN     1.53604     7.69305     1127.16
# r7_boro    0.205192     268.875     1.31284    0.449894     3.35524
# r8_boro     12.0521     109.145    0.834379     2.66757     171.074
# r9_boro         NaN         NaN     1.20097     5.75937     738.707
#
# [81 rows x 5 columns]

# %%
data.columns
# Out:
# Index(['RECORD', 'BBLE', 'B', 'BLOCK', 'LOT', 'EASEMENT', 'OWNER', 'BLDGCL',
#        'TAXCLASS', 'LTFRONT', 'LTDEPTH', 'EXT', 'STORIES', 'FULLVAL', 'AVLAND',
#        'AVTOT', 'EXLAND', 'EXTOT', 'EXCD1', 'STADDR', 'ZIP', 'EXMPTCL',
#        'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2', 'EXLAND2', 'EXTOT2',
#        'EXCD2', 'PERIOD', 'YEAR', 'VALTYPE', 'zip3', 'ltsize', 'bldsize',
#        'bldvol', 'r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7', 'r8', 'r9',
#        'r1_zip5', 'r2_zip5', 'r3_zip5', 'r4_zip5', 'r5_zip5', 'r6_zip5',
#        'r7_zip5', 'r8_zip5', 'r9_zip5', 'r1_zip3', 'r2_zip3', 'r3_zip3',
#        'r4_zip3', 'r5_zip3', 'r6_zip3', 'r7_zip3', 'r8_zip3', 'r9_zip3',
#        'r1_taxclass', 'r2_taxclass', 'r3_taxclass', 'r4_taxclass',
#        'r5_taxclass', 'r6_taxclass', 'r7_taxclass', 'r8_taxclass',
#        'r9_taxclass', 'r1_boro', 'r2_boro', 'r3_boro', 'r4_boro', 'r5_boro',
#        'r6_boro', 'r7_boro', 'r8_boro', 'r9_boro'],
#       dtype='object')

# %%
dropcols = ['RECORD','BBLE', 'B', 'BLOCK', 'LOT', 'EASEMENT',
       'OWNER', 'BLDGCL', 'TAXCLASS', 'LTFRONT', 'LTDEPTH', 'EXT', 'STORIES',
       'FULLVAL', 'AVLAND', 'AVTOT', 'EXLAND', 'EXTOT', 'EXCD1', 'STADDR',
       'ZIP', 'EXMPTCL', 'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2',
       'EXLAND2', 'EXTOT2', 'EXCD2', 'PERIOD', 'YEAR', 'VALTYPE', 'zip3','ltsize','bldsize','bldvol']  # drop the original columns
data = data.drop(columns = dropcols)
data.shape
# Out:
# (1070994, 45)

# %%
data.head().transpose()  # get the new dataset for following analysis after dropping the original columns
# Out:
#                        0             1           2           3             4
# r1             40.917782  53616.895011  261.796157   89.714219    669.074647
# r2           3781.487225  34245.431036  261.796157  836.980890  53676.325646
# r3                   NaN           NaN   87.265386  418.490445  53676.325646
# r4              8.079350   3959.018409   97.551991   34.913021    297.434763
# r5            746.667022   2528.648700   97.551991  325.717946  23861.620343
# r6                   NaN           NaN   32.517330  162.858973  23861.620343
# r7             18.413002  24127.602755  117.808271   40.371399    301.083591
# r8           1701.669251  15410.443966  117.808271  376.641401  24154.346541
# r9                   NaN           NaN   39.269424  188.320700  24154.346541
# r1_zip5         0.101384    132.849862    0.648668    0.222290      1.657807
# r2_zip5         6.178835     55.955990    0.427767    1.367601     87.705480
# r3_zip5              NaN           NaN    0.619186    2.969375    380.857258
# r4_zip5         0.145737     71.413756    1.759667    0.629770      5.365202
# r5_zip5         5.923505     20.060431    0.773905    2.584006    189.300472
# r6_zip5              NaN           NaN    0.608834    3.049270    446.770084
# r7_zip5         0.109146    143.019901    0.698326    0.239307      1.784717
# r8_zip5         6.496829     58.835770    0.449782    1.437985     92.219249
# r9_zip5              NaN           NaN    0.651164    3.122725    400.526192
# r1_zip3         0.114022    149.409774    0.729526    0.249999      1.864455
# r2_zip3         6.787490     61.468015    0.469905    1.502319     96.345034
# r3_zip3              NaN           NaN    0.614835    2.948509    378.180950
# r4_zip3         0.235797    115.544696    2.847073    1.018943      8.680689
# r5_zip3        11.577965     39.209723    1.512660    5.050646    370.002971
# r6_zip3              NaN           NaN    1.455224    7.288308   1067.861609
# r7_zip3         0.199068    260.850749    1.273661    0.436467      3.255105
# r8_zip3        11.659740    105.591475    0.807215    2.580725    165.504192
# r9_zip3              NaN           NaN    1.145298    5.492401    704.465027
# r1_taxclass     0.196150    257.027047    1.254990    0.430069      3.207390
# r2_taxclass     7.271010     65.846810    0.503379    1.609339    103.208361
# r3_taxclass          NaN           NaN    0.299788    1.437668    184.397796
# r4_taxclass     0.214174    104.948703    2.585983    0.925501      7.884629
# r5_taxclass     5.476385     18.546226    0.715489    2.388959    175.011654
# r6_taxclass          NaN           NaN    0.357651    1.791248    262.448386
# r7_taxclass     0.196047    256.891177    1.254327    0.429842      3.205694
# r8_taxclass     7.043211     63.783844    0.487609    1.558919     99.974865
# r9_taxclass          NaN           NaN    0.292565    1.403028    179.954862
# r1_boro         0.116884    153.160125    0.747838    0.256274      1.911255
# r2_boro         6.955979     62.993863    0.481569    1.539612     98.736649
# r3_boro              NaN           NaN    0.634440    3.042525    390.239652
# r4_boro         0.244447    119.783006    2.951507    1.056319      8.999107
# r5_boro        12.025207     40.724343    1.571092    5.245746    384.295698
# r6_boro              NaN           NaN    1.536037    7.693050   1127.163170
# r7_boro         0.205192    268.874880    1.312840    0.449894      3.355237
# r8_boro        12.052100    109.144722    0.834379    2.667569    171.073555
# r9_boro              NaN           NaN    1.200969    5.759374    738.707455

# %%
data.shape
# Out:
# (1070994, 45)

# %%
stats = data.describe().transpose()
stats.to_csv('stats_on_vars.csv')

# %%
data.to_csv('NY vars.csv', index=False)
data.describe()
# Out:
#                  r1            r2            r3            r4            r5  \
# count  1.070994e+06  1.070994e+06  1.014730e+06  1.070994e+06  1.070994e+06
# mean   2.042428e+02  5.393535e+02  2.591237e+02  9.761661e+00  2.809216e+01
# std    5.415145e+02  2.328457e+03  1.506428e+03  1.650396e+02  9.793034e+02
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    6.822222e+01  1.588709e+02  1.039510e+02  2.102001e+00  4.924562e+00
# 50%    1.490000e+02  4.915433e+02  2.434842e+02  4.490000e+00  1.470374e+01
# 75%    2.393939e+02  6.798457e+02  3.388430e+02  7.129856e+00  2.010562e+01
# max    3.423792e+05  1.097094e+06  1.097094e+06  1.540706e+05  4.914844e+05
#
#                  r6            r7            r8            r9       r1_zip5  \
# count  1.014730e+06  1.070994e+06  1.070994e+06  1.014730e+06  1.070994e+06
# mean   1.389770e+01  2.406875e+01  5.519153e+01  2.322487e+01  1.000000e+00
# std    6.513020e+02  2.091002e+02  1.285667e+03  7.144009e+02  2.089495e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.406421e+00  5.004488e+00  1.585566e+01  7.820933e+00  4.399191e-01
# 50%    7.254167e+00  8.372000e+00  2.643092e+01  1.285086e+01  9.370309e-01
# 75%    1.008511e+01  1.324858e+01  3.550182e+01  1.766667e+01  1.257657e+00
# max    4.914844e+05  1.540706e+05  8.249136e+05  4.936922e+05  1.456740e+03
#
#        ...   r9_taxclass       r1_boro       r2_boro       r3_boro  \
# count  ...  1.014730e+06  1.070994e+06  1.070994e+06  1.014730e+06
# mean   ...  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# std    ...  5.954906e+00  1.973076e+00  4.311932e+00  9.651447e+00
# min    ...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    ...  4.235581e-01  4.068480e-01  3.040950e-01  4.110671e-01
# 50%    ...  8.310907e-01  8.707793e-01  9.314494e-01  8.839266e-01
# 75%    ...  1.134792e+00  1.286936e+00  1.264172e+00  1.221820e+00
# max    ...  3.678109e+03  1.421391e+03  2.018084e+03  7.976132e+03
#
#             r4_boro       r5_boro       r6_boro       r7_boro       r8_boro  \
# count  1.070994e+06  1.070994e+06  1.014730e+06  1.070994e+06  1.070994e+06
# mean   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# std    2.155333e+01  3.151622e+01  3.656118e+01  9.464880e+00  2.397518e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.760378e-01  1.908059e-01  1.958781e-01  3.105171e-01  3.303801e-01
# 50%    7.403326e-01  6.318308e-01  5.486882e-01  5.987280e-01  6.265427e-01
# 75%    1.122373e+00  8.689950e-01  7.835890e-01  9.378290e-01  8.445907e-01
# max    2.130616e+04  1.756506e+04  2.321649e+04  8.978431e+03  1.791799e+04
#
#             r9_boro
# count  1.014730e+06
# mean   1.000000e+00
# std    2.566223e+01
# min    0.000000e+00
# 25%    3.620793e-01
# 50%    5.839451e-01
# 75%    8.103693e-01
# max    1.509849e+04
#
# [8 rows x 45 columns]

# %%
data_zs = (data - data.mean()) / data.std()  #standardize the new dataset 
data_zs.describe()
# Out:
#                  r1            r2            r3            r4            r5  \
# count  1.070994e+06  1.070994e+06  1.014730e+06  1.070994e+06  1.070994e+06
# mean   1.149114e-14 -2.068390e-14 -3.029112e-15 -3.510684e-15  3.864390e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.771695e-01 -2.316356e-01 -1.720120e-01 -5.914739e-02 -2.868586e-02
# 25%   -2.511854e-01 -1.634055e-01 -1.030070e-01 -4.641105e-02 -2.365722e-02
# 50%   -1.020153e-01 -2.053299e-02 -1.038182e-02 -3.194180e-02 -1.367138e-02
# 75%    6.491272e-02  6.033702e-02  5.291940e-02 -1.594651e-02 -8.155324e-03
# max    6.318852e+02  4.709361e+02  7.281028e+02  9.334783e+02  5.018427e+02
#
#                  r6            r7            r8            r9       r1_zip5  \
# count  1.014730e+06  1.070994e+06  1.070994e+06  1.014730e+06  1.070994e+06
# mean   2.835422e-15 -4.121245e-14 -4.453053e-15  7.070936e-16  1.486906e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2
# 4        1.324795  18.744481  33.778121  0.314816  ...    30.051669  0.461845
# 6        0.159235   9.732102  17.559056 -0.327419  ...    15.555233 -0.322265
# 7        0.828699   1.128088   0.669961  0.041462  ...     0.459932  0.128106
# ...           ...        ...        ...       ...  ...          ...       ...
# 1070989 -0.099615  -0.019672  -0.015768 -0.244909  ...    -0.029576 -0.249501
# 1070990 -0.110056  -0.028972  -0.022463 -0.330761  ...    -0.084901 -0.344041
# 1070991 -0.107512  -0.019660  -0.011572 -0.351154  ...     0.005101 -0.366497
# 1070992 -0.099528  -0.016264  -0.008517 -0.183647  ...     0.030354 -0.182041
# 1070993 -0.088332  -0.018736  -0.010741 -0.024357  ...     0.011969 -0.006632
#
#            r2_boro    r3_boro   r4_boro    r5_boro    r6_boro   r7_boro  \
# 2        -0.120232  -0.037876  0.090543   0.018121   0.014661  0.033053
# 3         0.125144   0.211629  0.002613   0.134716   0.183064 -0.058121
# 4        22.666558  40.329666  0.371131  12.161855  30.802154  0.248840
# 6        11.682088  20.933695  0.034130   6.390384  16.209923 -0.038113
# 7         1.195343   0.736455  0.196130   0.641792   0.540279  0.126704
# ...            ...        ...       ...        ...        ...       ...
# 1070989   0.049029  -0.019854 -0.023814  -0.003724  -0.011927 -0.059496
# 1070990   0.095212  -0.006086 -0.039035  -0.014927  -0.018097 -0.090604
# 1070991   0.080780   0.012917 -0.034963  -0.002790  -0.007428 -0.083027
# 1070992   0.172355   0.047043 -0.026803  -0.004027  -0.008279 -0.059235
# 1070993   0.096762   0.018873 -0.007076  -0.002382  -0.007147 -0.025875
#
#           r8_boro    r9_boro
# 2       -0.006908   0.007831
# 3        0.069554   0.185462
# 4        7.093735  28.746814
# 6        3.670840  14.938185
# 7        0.403041   0.559103
# ...           ...        ...
# 1070989 -0.004221  -0.016698
# 1070990 -0.019212  -0.025603
# 1070991 -0.004201  -0.011116
# 1070992  0.001273  -0.007052
# 1070993 -0.002713  -0.010011
#
# [1014730 rows x 45 columns]

# %%
pca = PCA(n_components = .99, svd_solver = 'full')   #? 
pca.fit(data_zs)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
plt.yticks(np.arange(0.05, 1.1, step=.1))
plt.xticks(np.arange(0, 20, step=2))
plt.axvline(x=6, linestyle='--')
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
pca = PCA(n_components = 6)  # try different number of components 
# pca = PCA(n_components = .85, svd_solver = 'full')
princ_comps = pca.fit_transform(data_zs)
pca.n_components_
# Out:
# 6

# %%
print(np.cumsum(pca.explained_variance_ratio_))
# Out:
# [0.64229274 0.77166568 0.85370281 0.88690137 0.91409047 0.93312987]

# %%
data_pca = pd.DataFrame(princ_comps, columns = ['PC' + str(i) for i in range(1, pca.n_components_+1)])
data_pca.shape
# Out:
# (1014730, 6)

# %%
data_pca.head()
# Out:
#           PC1       PC2        PC3       PC4       PC5       PC6
# 0   -0.184686  0.197663   0.171831  0.212054 -0.284836 -0.144634
# 1    0.770029 -0.634151  -0.033060 -0.042756 -0.124723 -0.063676
# 2  141.513876 -9.698562 -41.344029  7.327998 -8.598690  3.425683
# 3   73.545762 -6.664715 -21.422165  3.734308 -4.442540  1.661253
# 4    3.896078  1.130259  -0.221864 -0.671471  0.331294  0.148176

# %%
data_pca.describe()
# Out:
#                 PC1           PC2           PC3           PC4           PC5  \
# count  1.014730e+06  1.014730e+06  1.014730e+06  1.014730e+06  1.014730e+06
# mean   1.794055e-16  2.617701e-15 -1.633358e-16  6.410968e-16  4.882002e-17
# std    4.480040e+00  2.010653e+00  1.601108e+00  1.018533e+00  9.217492e-01
# min   -6.057298e-01 -2.129068e+02 -7.488028e+02 -3.222202e+02 -3.476072e+02
# 25%   -2.486451e-01 -5.085270e-01 -9.157830e-02 -5.069132e-02 -1.812771e-01
# 50%   -6.962385e-02 -1.612975e-01 -1.208980e-02  1.909235e-02  3.745884e-03
# 75%    5.753399e-02  1.617049e-01  1.909769e-01  6.895894e-02  9.103656e-02
# max    2.762527e+03  6.301687e+02  1.209659e+03  3.517259e+02  3.529286e+02
#
#                 PC6
# count  1.014730e+06
# mean   6.363301e-16
# std    7.713332e-01
# min   -1.789296e+02
# 25%   -1.345817e-01
# 50%    2.993862e-03
# 75%    9.633614e-02
# max    2.336570e+02

# %%
data_pca_zs = (data_pca - data_pca.mean()) / data_pca.std()  #standardze  the pca dataset
data_pca.describe()
# Out:
#                 PC1           PC2           PC3           PC4           PC5  \
# count  1.014730e+06  1.014730e+06  1.014730e+06  1.014730e+06  1.014730e+06
# mean   1.794055e-16  2.617701e-15 -1.633358e-16  6.410968e-16  4.882002e-17
# std    4.480040e+00  2.010653e+00  1.601108e+00  1.018533e+00  9.217492e-01
# min   -6.057298e-01 -2.129068e+02 -7.488028e+02 -3.222202e+02 -3.476072e+02
# 25%   -2.486451e-01 -5.085270e-01 -9.157830e-02 -5.069132e-02 -1.812771e-01
# 50%   -6.962385e-02 -1.612975e-01 -1.208980e-02  1.909235e-02  3.745884e-03
# 75%    5.753399e-02  1.617049e-01  1.909769e-01  6.895894e-02  9.103656e-02
# max    2.762527e+03  6.301687e+02  1.209659e+03  3.517259e+02  3.529286e+02
#
#                 PC6
# count  1.014730e+06
# mean   6.363301e-16
# std    7.713332e-01
# min   -1.789296e+02
# 25%   -1.345817e-01
# 50%    2.993862e-03
# 75%    9.633614e-02
# max    2.336570e+02

# %%
data_pca_zs.head(20)  # get the top 20 data
# Out:
#           PC1       PC2        PC3       PC4       PC5       PC6
# 0   -0.041224  0.098308   0.107320  0.208196 -0.309016 -0.187511
# 1    0.171880 -0.315396  -0.020648 -0.041978 -0.135311 -0.082553
# 2   31.587637 -4.823589 -25.822137  7.194661 -9.328665  4.441249
# 3   16.416318 -3.314702 -13.379588  3.666360 -4.819684  2.153742
# 4    0.869653  0.562135  -0.138569 -0.659253  0.359418  0.192104
# 5   -0.024093  0.176748   0.162351 -0.091566  0.003178  0.068535
# 6    0.025374  0.483890   0.176285 -0.164172  0.096489  0.180894
# 7    0.144408  1.264733   0.180547 -0.422519  0.446682  0.673817
# 8   -0.106703 -0.336184   0.139080  0.029687 -0.152654 -0.119106
# 9   -0.069914 -0.107756   0.149444 -0.024311 -0.083256 -0.035543
# 10  -0.073477 -0.129880   0.148440 -0.019082 -0.089977 -0.043635
# 11   0.082546  0.838878   0.192390 -0.248089  0.204336  0.310755
# 12   0.076746  0.802865   0.190757 -0.239576  0.193395  0.297581
# 13   0.076746  0.802865   0.190757 -0.239576  0.193395  0.297581
# 14   0.076746  0.802865   0.190757 -0.239576  0.193395  0.297581
# 15   0.076746  0.802865   0.190757 -0.239576  0.193395  0.297581
# 16   0.076746  0.802865   0.190757 -0.239576  0.193395  0.297581
# 17   0.076746  0.802865   0.190757 -0.239576  0.193395  0.297581
# 18   0.076746  0.802865   0.190757 -0.239576  0.193395  0.297581
# 19   0.076663  0.802351   0.190733 -0.239454  0.193239  0.297393

# %%
p=2   # try different 1, 3, 4
oop = 1/p
score1 = (((data_pca_zs).abs()**p).sum(axis=1))**oop
score1.head(10)  #score 1 ?
# Out:
# 0     0.443710
# 1     0.395386
# 2    42.969064
# 3    22.378702
# 4     1.300843
# 5     0.266964
# 6     0.578667
# 7     1.576412
# 8     0.426754
# 9     0.218217
# dtype: float64

# %%
score1.max()
# Out:
# 956.5346819567494

# %%
plt.hist(score1, bins =100, range=(0,1000))
plt.yscale('log')
plt.ylim(ymin=.1)
# Out:
# (0.1, 2021814.6614525714)

# %%
from keras.models import Model
from keras.layers import Input, Dense
# placeholder for input
data_in = Input(shape=(6,))
# dimension of the encoded data. Choose 3
encoded_dim = 3
# encoded representation of the data
encoded = Dense(encoded_dim, activation='tanh')(data_in)
# reconstruction of the input
decoded = Dense(6,activation='tanh')(encoded)
# this model maps the input data to the reconstructed data
autoencoder = Model(data_in, decoded)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# %%
# %%time
autoencoder.fit(data_pca_zs,data_pca_zs, epochs=5, shuffle=True, validation_data=(data_pca_zs,data_pca_zs))
# Out:
# Epoch 1/5
# 31711/31711 [==============================] - 19s 577us/step - loss: 0.7388 - val_loss: 0.8962
# Epoch 2/5
# 31711/31711 [==============================] - 18s 557us/step - loss: 0.7284 - val_loss: 0.8946
# Epoch 3/5
# 31711/31711 [==============================] - 18s 572us/step - loss: 1.3285 - val_loss: 0.8943
# Epoch 4/5
# 31711/31711 [==============================] - 18s 558us/step - loss: 0.8809 - val_loss: 0.8942
# Epoch 5/5
# 31711/31711 [==============================] - 18s 565us/step - loss: 0.6175 - val_loss: 0.8938
# Wall time: 1min 30s

# %%
# %%time
pca_out = autoencoder.predict(data_pca_zs)
error = pca_out - data_pca_zs
p=2                                 # try different p in socre 2, like 1, 3, 4 
oop=1/p
# score2 =np.power(np.sum(np.power(error, p), axis=1),oop)
score2 = ((error.abs()**p).sum(axis=1))**oop
# Out:
# Wall time: 5.82 s

# %%
score2.head(10)
# Out:
# 0     0.139136
# 1     0.265118
# 2    42.875485
# 3    22.457771
# 4     0.965200
# 5     0.223868
# 6     0.304050
# 7     0.648358
# 8     0.095072
# 9     0.145684
# dtype: float64

# %%
scores = pd.DataFrame(score1)
scores.columns=['score1']
scores['score2'] = score2
scores.head()
# Out:
#       score1     score2
# 0   0.443710   0.139136
# 1   0.395386   0.265118
# 2  42.969064  42.875485
# 3  22.378702  22.457771
# 4   1.300843   0.965200

# %%
scores['score1 rank'] = scores['score1'].rank()
scores['score2 rank'] = scores['score2'].rank()
scores.head(10)
# Out:
#       score1     score2  score1 rank  score2 rank
# 0   0.443710   0.139136     632427.0     776159.0
# 1   0.395386   0.265118     599307.0     937021.0
# 2  42.969064  42.875485    1014558.0    1014563.0
# 3  22.378702  22.457771    1014297.0    1014346.0
# 4   1.300843   0.965200     969998.0     990823.0
# 5   0.266964   0.223868     433246.0     913186.0
# 6   0.578667   0.304050     733478.0     950495.0
# 7   1.576412   0.648358     978830.0     983492.0
# 8   0.426754   0.095072     621804.0     600192.0
# 9   0.218217   0.145684     324868.0     794316.0

# %%
scores['final'] = (scores['score1 rank'] + scores['score2 rank'])/2
scores_sorted = scores.sort_values(by='final', ascending=False)
scores_sorted.head(20)
# Out:
#             score1      score2  score1 rank  score2 rank      final
# 877261  956.534682  955.569159    1014730.0    1014730.0  1014730.0
# 83281   848.219885  847.646612    1014729.0    1014729.0  1014729.0
# 530358  562.874738  562.170711    1014728.0    1014728.0  1014728.0
# 658754  515.065581  513.512927    1014727.0    1014727.0  1014727.0
# 38272   398.859694  397.199441    1014726.0    1014726.0  1014726.0
# 42584   357.141625  356.393018    1014725.0    1014725.0  1014725.0
# 32522   331.499952  329.988387    1014724.0    1014724.0  1014724.0
# 406     313.322440  312.502339    1014723.0    1014723.0  1014723.0
# 476771  293.625838  291.450234    1014722.0    1014722.0  1014722.0
# 113099  281.794980  280.490778    1014721.0    1014721.0  1014721.0
# 46263   263.255276  261.852251    1014720.0    1014720.0  1014720.0
# 144840  258.702951  256.887235    1014719.0    1014719.0  1014719.0
# 659762  252.136840  251.042291    1014718.0    1014718.0  1014718.0
# 103309  243.034882  241.149796    1014717.0    1014717.0  1014717.0
# 885027  239.408865  238.454084    1014715.0    1014716.0  1014715.5
# 912495  240.516367  238.331421    1014716.0    1014715.0  1014715.5
# 882486  234.871525  234.267372    1014714.0    1014714.0  1014714.0
# 83280   232.804074  231.688230    1014713.0    1014713.0  1014713.0
# 736523  231.547228  229.656419    1014712.0    1014712.0  1014712.0
# 718166  229.913799  228.047776    1014711.0    1014711.0  1014711.0

# %%
scores_sorted.tail(10)
# Out:
#           score1    score2  score1 rank  score2 rank    final
# 963525  0.043424  0.008425       2018.5         24.5  1021.50
# 966441  0.041339  0.011612       1604.0        331.0   967.50
# 971289  0.041896  0.010965       1694.0        204.0   949.00
# 965194  0.042392  0.009073       1802.0         45.0   923.50
# 962680  0.041521  0.010200       1630.0        109.0   869.50
# 966440  0.039959  0.010814       1358.0        171.0   764.50
# 966879  0.037077  0.012244        926.5        477.0   701.75
# 966882  0.037077  0.012244        926.5        476.0   701.25
# 962679  0.037104  0.010619        928.0        158.0   543.00
# 962678  0.034480  0.011425        624.0        284.0   454.00

# %%
plt.hist(score1, bins =100, range=(0,1000))
plt.yscale('log')
plt.ylim(ymin=.1)
# Out:
# (0.1, 2021814.6614525714)

# %%
plt.hist(score2, bins =100, range=(0,1000))
plt.yscale('log')
plt.ylim(ymin=.1)
# Out:
# (0.1, 2023187.7894344565)

# %%
sns.distplot(scores['final'])

# %%
# r7_taxclass  -0.089316  -0.238251  -0.235213   0.715158
# r8_taxclass  35.864664   9.659517   7.083295  14.729170
# r9_taxclass  49.215773  40.148068  15.680430  40.617270
# r1_boro      -0.399423  -0.474481  -0.440366  -0.116429
# r2_boro      11.158388   2.913035  11.005364   4.794580
# r3_boro       1.688822   1.224725  10.506508   2.854921
# r4_boro      -0.030729  -0.021749   0.041881   0.041600
# r5_boro       2.179683   2.761454  19.834535   1.368000
# r6_boro       0.619759   2.113918  34.852625   1.152312
# r7_boro       0.035769  -0.066155  -0.018144   0.037215
# r8_boro      13.443936   3.123893  13.262762   1.524607
# r9_boro       4.548515   2.727634  27.116142   2.067309
#
# [45 rows x 100 columns]

# %%
NY_data_orig.head()
# Out:
#    RECORD        BBLE  B  BLOCK  LOT EASEMENT                  OWNER BLDGCL  \
# 0       1  1000010101  1      1  101      NaN  U S GOVT LAND & BLDGS     P7
# 1       2  1000010201  1      1  201      NaN  U S GOVT LAND & BLDGS     Z9
# 2       3  1000020001  1      2    1      NaN  DEPT OF GENERAL SERVI     Y7
# 3       4  1000020023  1      2   23      NaN  DEPARTMENT OF BUSINES     T2
# 4       5  1000030001  1      3    1      NaN   PARKS AND RECREATION     Q1
#
#   TAXCLASS  LTFRONT  ...  BLDFRONT BLDDEPTH      AVLAND2       AVTOT2  \
# 0        4      500  ...         0        0    3775500.0    8613000.0
# 1        4       27  ...         0        0   11111400.0   80690400.0
# 2        4      709  ...       709      564   32321790.0   40179510.0
# 3        4      793  ...        85      551   13644000.0   15750000.0
# 4        4      323  ...        89       57  106348680.0  107758350.0
#
#        EXLAND2       EXTOT2  EXCD2  PERIOD     YEAR VALTYPE
# 0    3775500.0    8613000.0    NaN   FINAL  2010/11   AC-TR
# 1   11111400.0   80690400.0    NaN   FINAL  2010/11   AC-TR
# 2   32321790.0   40179510.0    NaN   FINAL  2010/11   AC-TR
# 3   13644000.0   15750000.0    NaN   FINAL  2010/11   AC-TR
# 4  106348680.0  107758350.0    NaN   FINAL  2010/11   AC-TR
#
# [5 rows x 32 columns]

# %%
scores.head()
# Out:
#       score1     score2  score1 rank  score2 rank      final
# 0   0.443710   0.139136     632427.0     776159.0   704293.0
# 1   0.395386   0.265118     599307.0     937021.0   768164.0
# 2  42.969064  42.875485    1014558.0    1014563.0  1014560.5
# 3  22.378702  22.457771    1014297.0    1014346.0  1014321.5
# 4   1.300843   0.965200     969998.0     990823.0   980410.5

# %%
NY_data_with_scores = NY_data_orig.join(scores)
NY_data_with_scores.set_index('RECORD',inplace=True)
NY_data_with_scores.head()
# Out:
#               BBLE  B  BLOCK  LOT EASEMENT                  OWNER BLDGCL  \
# RECORD
# 1       1000010101  1      1  101      NaN  U S GOVT LAND & BLDGS     P7
# 2       1000010201  1      1  201      NaN  U S GOVT LAND & BLDGS     Z9
# 3       1000020001  1      2    1      NaN  DEPT OF GENERAL SERVI     Y7
# 4       1000020023  1      2   23      NaN  DEPARTMENT OF BUSINES     T2
# 5       1000030001  1      3    1      NaN   PARKS AND RECREATION     Q1
#
#        TAXCLASS  LTFRONT  LTDEPTH  ...       EXTOT2  EXCD2  PERIOD     YEAR  \
# RECORD                             ...
# 1             4      500     1046  ...    8613000.0    NaN   FINAL  2010/11
# 2             4       27        0  ...   80690400.0    NaN   FINAL  2010/11
# 3             4      709      564  ...   40179510.0    NaN   FINAL  2010/11
# 4             4      793      551  ...   15750000.0    NaN   FINAL  2010/11
# 5             4      323     1260  ...  107758350.0    NaN   FINAL  2010/11
#
#         VALTYPE     score1     score2  score1 rank score2 rank      final
# RECORD
# 1         AC-TR   0.443710   0.139136     632427.0    776159.0   704293.0
# 2         AC-TR   0.395386   0.265118     599307.0    937021.0   768164.0
# 3         AC-TR  42.969064  42.875485    1014558.0   1014563.0  1014560.5
# 4         AC-TR  22.378702  22.457771    1014297.0   1014346.0  1014321.5
# 5         AC-TR   1.300843   0.965200     969998.0    990823.0   980410.5
#
# [5 rows x 36 columns]

# %%
NY_data_top_n = NY_data_with_scores.sort_values(['final'], ascending = False).head(200)
NY_data_top_n
# Out:
#               BBLE  B  BLOCK   LOT EASEMENT                  OWNER BLDGCL  \
# RECORD
# 877262  4120230093  4  12023    93      NaN        LAWSON, CECIL M     A1
# 83282   1012311299  1   1231  1299      NaN          GIRON FABIO M     R4
# 530359  3076940021  3   7694    21      NaN          BALZANO, JEAN     B1
# 658755  4029030025  4   2903    25      NaN      ROAN, MIZCHELLE M     B2
# 38273   1007750002  1    775     2      NaN  302 EIGHTH AVENUE LLC     S5
# ...            ... ..    ...   ...      ...                    ...    ...
# 736529  4058630568  4   5863   568      NaN             VITA MAURA     B2
# 224398  2047960147  2   4796   147      NaN        ABDELAZIZ, ELSA     B2
# 877451  4120270106  4  12027   106      NaN            JANET AARON     B3
# 778277  4081480041  4   8148    41      NaN       JOSEPH SALVEMINI     A9
# 54019   1009401169  1    940  1169      NaN          PLIOTIS, DINA     R4
#
#        TAXCLASS  LTFRONT  LTDEPTH  ...  EXTOT2  EXCD2  PERIOD     YEAR  \
# RECORD                             ...
# 877262        1       26      100  ...     NaN    NaN   FINAL  2010/11
# 83282         2        0        0  ...     NaN    NaN   FINAL  2010/11
# 530359        1       25      100  ...     NaN    NaN   FINAL  2010/11
# 658755        1       20      100  ...     NaN    NaN   FINAL  2010/11
# 38273        2A       24       95  ...     NaN    NaN   FINAL  2010/11
# ...         ...      ...      ...  ...     ...    ...     ...      ...
# 736529        1       32      100  ...     NaN    NaN   FINAL  2010/11
# 224398        1       25       94  ...     NaN    NaN   FINAL  2010/11
# 877451        1       40      100  ...     NaN    NaN   FINAL  2010/11
# 778277        1       60       41  ...     NaN    NaN   FINAL  2010/11
# 54019         2        0        0  ...  2090.0    NaN   FINAL  2010/11
#
#         VALTYPE      score1      score2  score1 rank score2 rank      final
# RECORD
# 877262    AC-TR  956.534682  955.569159    1014730.0   1014730.0  1014730.0
# 83282     AC-TR  848.219885  847.646612    1014729.0   1014729.0  1014729.0
# 530359    AC-TR  562.874738  562.170711    1014728.0   1014728.0  1014728.0
# 658755    AC-TR  515.065581  513.512927    1014727.0   1014727.0  1014727.0
# 38273     AC-TR  398.859694  397.199441    1014726.0   1014726.0  1014726.0
# ...         ...         ...         ...          ...         ...        ...
# 736529    AC-TR   39.689818   37.869344    1014537.0   1014533.0  1014535.0
# 224398    AC-TR   39.532357   37.929444    1014535.0   1014534.0  1014534.5
# 877451    AC-TR   39.664901   37.517144    1014536.0   1014531.0  1014533.5
# 778277    AC-TR   39.035721   37.951838    1014531.0   1014535.0  1014533.0
# 54019     AC-TR   39.453270   37.813206    1014532.0   1014532.0  1014532.0
#
# [200 rows x 36 columns]

# %%
data_zs_top_n['RECORD'] = (data_zs_top_n.index + 1).astype(int)
data_zs_top_n.set_index('RECORD',inplace=True)
data_zs_top_n
# Out:
# <ipython-input-100-22eaf6cbeac5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_zs_top_n['RECORD'] = (data_zs_top_n.index + 1).astype(int)
#                 r1          r2          r3          r4          r5  \
# RECORD
# 917942    0.673618   28.152477   14.452246   16.467167  323.464841
# 85886    -0.161066  470.936066  728.102787    0.258504  501.842700
# 556609  143.135684   10.473602   16.374867  210.279988   11.341162
# 690833    0.994768  259.597080  133.698727    1.866076  264.189726
# 39770     2.185560   68.214978    7.966189    1.376501   27.757326
# ...            ...         ...         ...         ...         ...
# 771156   -0.342466    1.856657    1.441905   -0.032145    1.148809
# 235761   16.770506    2.333423    0.819178    0.054711   -0.016344
# 918184   -0.310582   10.244804   16.021218    0.035506   10.762843
# 814287   -0.128408   27.827003   21.512835   -0.029547    2.390721
# 56082     0.755089    7.013700    0.574586    0.502204    2.574329
#
#                 r6          r7          r8          r9     r1_zip5  ...  \
# RECORD                                                              ...
# 917942  162.114571   33.850184  641.580261  384.865071    2.047192  ...
# 85886   754.596914    0.136737  383.954090  691.025073   -0.223214  ...
# 556609   17.074465  167.132131    8.681735   15.668770  198.897029  ...
# 690833  132.405708    1.483724  211.714906  126.996998    1.245862  ...
# 39770     3.192454    2.871452   55.740385    7.689802    1.058351  ...
# ...            ...         ...         ...         ...         ...  ...
# 771156    0.863908   -0.074664    1.659010    1.498931   -0.421376  ...
# 235761   -0.016699   19.868479    2.047569    0.908028   31.103883  ...
# 918184   16.204901   -0.037506    8.495266   15.333193   -0.330099  ...
# 814287    1.797582   -0.079330    2.779083    2.506797   -0.108998  ...
# 56082     0.239589    1.204407    5.861949    0.675935    0.137172  ...
#
#         r9_taxclass     r1_boro     r2_boro     r3_boro     r4_boro  \
# RECORD
# 917942   343.849612    1.233985   26.537089    7.434028   20.971307
# 85886    617.492307   -0.337400  467.791398  826.314659    0.027196
# 556609    13.865715  163.010273    9.718640    9.291597  222.683788
# 690833   113.369753    1.766025  244.812063   68.896086    2.402048
# 39770    127.141108    1.502330   67.757913    9.131306    0.286209
# ...             ...         ...         ...         ...         ...
# 771156    25.079201   -0.449331    1.737550    0.728234   -0.012055
# 235761     0.672714   35.406379    3.288028    0.636771    0.119534
# 918184    13.565780   -0.396509    9.648396    8.242708    0.073981
# 814287    20.817337   -0.094707   26.230135   11.073199   -0.008752
# 56082     11.511400    0.380856    6.965069    0.743600    0.083655
#
#            r5_boro     r6_boro     r7_boro     r8_boro     r9_boro
# RECORD
# 917942  376.629121  192.472743   58.862330  747.314093  435.399024
# 85886   251.122889  634.976476   -0.043652  145.800085  588.315420
# 556609   18.007131   31.644181  215.211588   11.739334   24.006748
# 690833  307.611928  157.200120    2.670115  246.611542  143.670623
# 39770    13.873397    2.677023    0.629615   21.144753    6.535674
# ...            ...         ...         ...         ...         ...
# 771156    1.339291    1.023680   -0.035441    1.940689    1.693564
# 235761   -0.013409   -0.021417   30.580260    2.565481    1.072529
# 918184   12.533426   19.237675    0.029070    9.903488   17.344386
# 814287    2.785315    2.132210   -0.043542    3.245339    2.833772
# 56082     1.270913    0.192217    0.219201    2.200958    0.564190
#
# [200 rows x 45 columns]

# %%
NY_data_top_n.to_csv('NY_top.csv', index=True)
data_zs_top_n.to_csv('data_zs_top.csv', index=True)

# %%
data_zs_top_n_abs = data_zs_top_n.abs()
data_heatmap = data_zs_top_n.abs().head(20)
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
print('Duration: ', datetime.now() - start_time)
# Out:
# Duration:  0:20:03.740029
